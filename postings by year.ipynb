# %%
import pandas as pd
import numpy as np
import io

import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# using Basemap for map visualization. Installed it with "conda install basemap"
from mpl_toolkits.basemap import Basemap
from matplotlib import animation, rc
from IPython.display import HTML

# %%
worldCities = pd.read_csv("./world-cities.csv", encoding='latin1')
# worldCities.head()

# %%
dip = pd.read_csv("./diplomaticPosting.tsv", sep="\t")
# dip.head()

# %%
dip.location.replace("U.S.A.", "United States", inplace=True)
dip.location.replace("U.S.S.R.", "Russia", inplace=True)

dip.location.replace("Bosnia Herzegovina", "Bosnia and Herzegovina", inplace=True)
dip.location.replace("Bosnia-Herzegovina", "Bosnia and Herzegovina", inplace=True)
dip.location.replace("Buda-Pest", "Budapest", inplace=True)
dip.location.replace("Camboadia", "Cambodia", inplace=True)

dip.location.replace('China (Counsellor)', 'China', inplace=True)
dip.location.replace('China, 1912', 'China', inplace=True)
dip.location.replace('Israel (did not proceed)', 'Israel', inplace=True)
dip.location.replace('Morocco (Rabat)', 'Morocco', inplace=True)
dip.location.replace('Russia (Counsellor)', 'Russia', inplace=True)
dip.location.replace('Sir Lanka', "Sri Lanka", inplace=True)
dip.location.replace("Tanganykia", "Tanzania", inplace=True)
dip.location.replace('The Netherlands', "Netherlands", inplace=True)
dip.location.replace('Zaire' "Democratic Republic of Congo", inplace=True)
dip.location.replace("Rhodesia", "Zimbabwe", inplace=True)
dip.location.replace("Southern Rhodesia", "Zimbabwe", inplace=True)
dip.location.replace("Northern Rhodesia", "Zimbabwe", inplace=True)

# %%
# np.unique(dip.location.values.astype(str))

# %%
known_countries = np.unique(worldCities.country.tolist())
known_cities = np.unique(worldCities["name"].tolist())

# %%
# known_countries

# %%
dip["country"] = dip.location[dip.location.isin(known_countries)]

# %%
dip["city"] = dip.location[dip.location.isin(known_cities)]

# %%
# dip

# %%
dip = dip.merge(worldCities, left_on='city', right_on='name', how='left')

# %%
dip = dip.drop('name', axis=1)
dip = dip.drop('subcountry', axis=1)
dip = dip.drop('geonameid', axis=1)

# %%
dip["country"] = dip.country_y.fillna(dip.country_x)
dip = dip.drop('country_y', axis=1)
dip = dip.drop('country_x', axis=1)

# %%
# dip.head()

# %%
countryCapitals = pd.read_csv("./country-capitals.csv")
# countryCapitals.head()

# %%
dip = dip.merge(countryCapitals, how='left', left_on='country', right_on='CountryName')
dip = dip.drop("CountryName", axis=1)

# %%
dip["city"] = dip.city.fillna(dip.CapitalName)
# dip

# %%
countryCapitals.head()
# Out:
#                                 CountryName        CapitalName  \
# 0                                Somaliland           Hargeisa
# 1  South Georgia and South Sandwich Islands  King Edward Point
# 2       French Southern and Antarctic Lands  Port-aux-Français
# 3                                 Palestine          Jerusalem
# 4                             Aland Islands          Mariehamn
#
#    CapitalLatitude  CapitalLongitude CountryCode ContinentName
# 0         9.550000         44.050000         NaN        Africa
# 1       -54.283333        -36.500000          GS    Antarctica
# 2       -49.350000         70.216667          TF    Antarctica
# 3        31.766667         35.233333          PS          Asia
# 4        60.116667         19.900000          AX        Europe

# %%
dip1989 = dip[dip.yearPostingStart == 1989.].country.value_counts().to_frame().merge(countryCapitals, left_index=True, right_on='CountryName')
dip1989.head()
# Out:
#      country    CountryName       CapitalName  CapitalLatitude  \
# 227        8  United States  Washington  D.C.        38.883333
# 45         5         Canada            Ottawa        45.416667
# 201        3          Spain            Madrid        40.400000
# 20         3      Australia          Canberra       -35.266667
# 176        2        Romania         Bucharest        44.433333
#
#      CapitalLongitude CountryCode    ContinentName
# 227        -77.000000          US  Central America
# 45         -75.700000          CA  Central America
# 201         -3.683333          ES           Europe
# 20         149.133333          AU        Australia
# 176         26.100000          RO           Europe

# %%
for year in np.unique(dip.yearPostingStart.tolist()):
    print(year)

    dip_year = dip[dip.yearPostingStart == year].country.value_counts().to_frame().merge(countryCapitals, left_index=True, right_on='CountryName')

    plt.figure(figsize=(120,60))
    plt.title("New Diplomatic Postings {}".format(int(year)), fontsize=120)
    m = Basemap(resolution='c', # c, l, i, h, f or None
                projection='cyl',
                fix_aspect=True)
    m.drawcoastlines()#color='#f2f2f2',lake_color='#46bcec')
    m.drawcountries(antialiased=False)
    m.scatter(dip_year.CapitalLongitude, dip_year.CapitalLatitude, s=dip_year.country*6000, alpha=0.4)

    plt.savefig("postings_by_year/New_diplomatic_postings_{}".format(int(year))+".jpg")
    plt.close()
# Out:
# 1764.0
# /Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3222: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3231: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
# 1769.0
# 1771.0
# 1772.0
# 1775.0
# 1776.0
# 1777.0
# 1779.0
# 1780.0
# 1783.0
# 1784.0
# 1785.0
# 1787.0
# 1788.0
# 1789.0
# 1790.0
# 1791.0
# 1792.0
# 1793.0
# 1794.0
# 1795.0
# 1796.0
# 1798.0
# 1799.0
# 1800.0
# 1801.0
# 1802.0
# 1803.0
# 1804.0
# 1806.0
# 1807.0
# 1808.0
# 1809.0
# 1810.0
# 1811.0
# 1812.0
# 1813.0
# 1814.0
# 1815.0
# 1816.0
# 1817.0
# 1820.0
# 1821.0
# 1822.0
# 1823.0
# 1824.0
# 1825.0
# 1826.0
# 1827.0
# 1828.0
# 1829.0
# 1830.0
# 1831.0
# 1832.0
# 1833.0
# 1834.0
# 1835.0
# 1836.0
# 1837.0
# 1838.0
# 1839.0
# 1840.0
# 1841.0
# 1842.0
# 1843.0
# 1844.0
# 1845.0
# 1846.0
# 1847.0
# 1848.0
# 1849.0
# 1850.0
# 1851.0
# 1852.0
# 1853.0
# 1854.0
# 1855.0
# 1856.0
# 1857.0
# 1858.0
# 1859.0
# 1860.0
# 1861.0
# 1862.0
# 1863.0
# 1864.0
# 1865.0
# 1866.0
# 1867.0
# 1868.0
# 1869.0
# 1870.0
# 1871.0
# 1872.0
# 1873.0
# 1874.0
# 1875.0
# 1876.0
# 1877.0
# 1878.0
# 1879.0
# 1880.0
# 1881.0
# 1882.0
# 1883.0
# 1884.0
# 1885.0
# 1886.0
# 1887.0
# 1888.0
# 1889.0
# 1890.0
# 1891.0
# 1892.0
# 1893.0
# 1894.0
# 1895.0
# 1896.0
# 1897.0
# 1898.0
# 1899.0
# 1900.0
# 1901.0
# 1902.0
# 1903.0
# 1904.0
# 1905.0
# 1906.0
# 1907.0
# 1908.0
# 1909.0
# 1910.0
# 1911.0
# 1912.0
# 1913.0
# 1914.0
# 1915.0
# 1916.0
# 1917.0
# 1918.0
# 1919.0
# 1920.0
# 1921.0
# 1922.0
# 1923.0
# 1924.0
# 1925.0
# 1926.0
# 1927.0
# 1928.0
# 1929.0
# 1930.0
# 1931.0
# 1932.0
# 1933.0
# 1934.0
# 1935.0
# 1936.0
# 1937.0
# 1938.0
# 1939.0
# 1940.0
# 1941.0
# 1942.0
# 1943.0
# 1944.0
# 1945.0
# 1946.0
# 1947.0
# 1948.0
# 1949.0
# 1950.0
# 1951.0
# 1952.0
# 1953.0
# 1954.0
# 1955.0
# 1956.0
# 1957.0
# 1958.0
# 1959.0
# 1960.0
# 1961.0
# 1962.0
# 1963.0
# 1964.0
# 1965.0
# 1966.0
# 1967.0
# 1968.0
# 1969.0
# 1970.0
# 1971.0
# 1972.0
# 1973.0
# 1974.0
# 1975.0
# 1976.0
# 1977.0
# 1978.0
# 1979.0
# 1980.0
# 1981.0
# 1982.0
# 1983.0
# 1984.0
# 1985.0
# 1986.0
# 1987.0
# 1988.0
# 1989.0
# 1990.0
# 1991.0
# 1992.0
# 1993.0
# 1994.0
# 1995.0
# 1996.0
# 1997.0
# 1998.0
# 1999.0
# 2000.0
# 2001.0
# 2002.0
# 2003.0
# 2004.0
# 2005.0
# 2006.0
# 2007.0
# 2008.0
# 2009.0
# 2010.0
# 2011.0
# 2012.0
# 2013.0
# 2014.0
# 2015.0
# 2016.0
# 2017.0
# 2018.0
# 18881894.0
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
#
# KeyboardInterrupt
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-20-9ba48ec212e4>", line 15, in <module>
#     plt.savefig("postings_by_year/New_diplomatic_postings_{}".format(int(year))+".jpg")
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py", line 710, in savefig
#     res = fig.savefig(*args, **kwargs)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py", line 2035, in savefig
#     self.canvas.print_figure(fname, **kwargs)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/matplotlib/backend_bases.py", line 2263, in print_figure
#     **kwargs)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py", line 584, in print_jpg
#     return background.save(filename_or_obj, format='jpeg', **options)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/PIL/Image.py", line 1950, in save
#     save_handler(self, fp, filename)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/PIL/JpegImagePlugin.py", line 762, in _save
#     ImageFile._save(im, fp, [("jpeg", (0, 0)+im.size, 0, rawmode)], bufsize)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/PIL/ImageFile.py", line 513, in _save
#     s = e.encode_to_file(fh, bufsize)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 1806, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1090, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 311, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 345, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/inspect.py", line 1480, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/inspect.py", line 1438, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/inspect.py", line 693, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/inspect.py", line 739, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/posixpath.py", line 386, in realpath
#     path, ok = _joinrealpath(filename[:0], filename, {})
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/posixpath.py", line 420, in _joinrealpath
#     if not islink(newpath):
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/posixpath.py", line 169, in islink
#     st = os.lstat(path)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 1809, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1371, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1279, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1128, in structured_traceback
#     tb_offset)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1066, in format_exception_as_a_whole
#     records = self.get_records(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1105, in get_records
#     traceback.print_exc(file=self.ostream)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/traceback.py", line 159, in print_exc
#     print_exception(*sys.exc_info(), limit=limit, file=file, chain=chain)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/traceback.py", line 100, in print_exception
#     type(value), value, tb, limit=limit).format(chain=chain):
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/traceback.py", line 510, in __init__
#     self._load_lines()
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/traceback.py", line 522, in _load_lines
#     self.__context__._load_lines()
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/traceback.py", line 522, in _load_lines
#     self.__context__._load_lines()
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/traceback.py", line 520, in _load_lines
#     frame.line
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/traceback.py", line 282, in line
#     self._line = linecache.getline(self.filename, self.lineno).strip()
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/linecache.py", line 16, in getline
#     lines = getlines(filename, module_globals)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/linecache.py", line 47, in getlines
#     return updatecache(filename, module_globals)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/linecache.py", line 137, in updatecache
#     lines = fp.readlines()
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/codecs.py", line 318, in decode
#     def decode(self, input, final=False):
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2879, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 1821, in showtraceback
#     print('\n' + self.get_exception_only(), file=sys.stderr)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/ipykernel/iostream.py", line 352, in write
#     self.pub_thread.schedule(lambda : self._buffer.write(string))
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/ipykernel/iostream.py", line 190, in schedule
#     self._event_pipe.send(event_id)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/zmq/backend/cffi/socket.py", line 189, in send
#     _retry_sys_call(C.zmq_msg_send, zmq_msg, self._zmq_socket, flags)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/zmq/backend/cffi/utils.py", line 48, in _retry_sys_call
#     rc = f(*args)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 1806, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1090, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 311, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 345, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/inspect.py", line 1480, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/inspect.py", line 1438, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/inspect.py", line 693, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/inspect.py", line 739, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/posixpath.py", line 386, in realpath
#     path, ok = _joinrealpath(filename[:0], filename, {})
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/posixpath.py", line 420, in _joinrealpath
#     if not islink(newpath):
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/posixpath.py", line 169, in islink
#     st = os.lstat(path)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    1805                         # in the engines. This should return a list of strings.
# -> 1806                         stb = value._render_traceback_()
#    1807                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py in get_records(self, etb, number_of_lines_of_context, tb_offset)
#    1089             # (5 blanks lines) where none should be returned.
# -> 1090             return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#    1091         except UnicodeDecodeError:
#
# ~/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py in wrapped(*args, **kwargs)
#     310         try:
# --> 311             return f(*args, **kwargs)
#     312         finally:
#
# ~/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py in _fixed_getinnerframes(etb, context, tb_offset)
#     344
# --> 345     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#     346     # If the error is at the console, don't build any context, since it would
#
# ~/anaconda3/lib/python3.6/inspect.py in getinnerframes(tb, context)
#    1479     while tb:
# -> 1480         frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#    1481         framelist.append(FrameInfo(*frameinfo))
#
# ~/anaconda3/lib/python3.6/inspect.py in getframeinfo(frame, context)
#    1437
# -> 1438     filename = getsourcefile(frame) or getfile(frame)
#    1439     if context > 0:
#
# ~/anaconda3/lib/python3.6/inspect.py in getsourcefile(object)
#     692     # only return a non-existent filename if the module has a PEP 302 loader
# --> 693     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#     694         return filename
#
# ~/anaconda3/lib/python3.6/inspect.py in getmodule(object, _filename)
#     738             modulesbyfile[f] = modulesbyfile[
# --> 739                 os.path.realpath(f)] = module.__name__
#     740     if file in modulesbyfile:
#
# ~/anaconda3/lib/python3.6/posixpath.py in realpath(filename)
#     385     filename = os.fspath(filename)
# --> 386     path, ok = _joinrealpath(filename[:0], filename, {})
#     387     return abspath(path)
#
# ~/anaconda3/lib/python3.6/posixpath.py in _joinrealpath(path, rest, seen)
#     419         newpath = join(path, name)
# --> 420         if not islink(newpath):
#     421             path = newpath
#
# ~/anaconda3/lib/python3.6/posixpath.py in islink(path)
#     168     try:
# --> 169         st = os.lstat(path)
#     170     except (OSError, AttributeError):
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    1808                         stb = self.InteractiveTB.structured_traceback(etype,
# -> 1809                                             value, tb, tb_offset=tb_offset)
#    1810
#
# ~/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1370         return FormattedTB.structured_traceback(
# -> 1371             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1372
#
# ~/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1278             return VerboseTB.structured_traceback(
# -> 1279                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1280             )
#
# ~/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1127         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
# -> 1128                                                                tb_offset)
#    1129
#
# ~/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1065         head = self.prepare_header(etype, self.long_header)
# -> 1066         records = self.get_records(etb, number_of_lines_of_context, tb_offset)
#    1067
#
# ~/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py in get_records(self, etb, number_of_lines_of_context, tb_offset)
#    1104             inspect_error()
# -> 1105             traceback.print_exc(file=self.ostream)
#    1106             info('\nUnfortunately, your original traceback can not be constructed.\n')
#
# ~/anaconda3/lib/python3.6/traceback.py in print_exc(limit, file, chain)
#     158     """Shorthand for 'print_exception(*sys.exc_info(), limit, file)'."""
# --> 159     print_exception(*sys.exc_info(), limit=limit, file=file, chain=chain)
#     160
#
# ~/anaconda3/lib/python3.6/traceback.py in print_exception(etype, value, tb, limit, file, chain)
#      99     for line in TracebackException(
# --> 100             type(value), value, tb, limit=limit).format(chain=chain):
#     101         print(line, file=file, end="")
#
# ~/anaconda3/lib/python3.6/traceback.py in __init__(self, exc_type, exc_value, exc_traceback, limit, lookup_lines, capture_locals, _seen)
#     509         if lookup_lines:
# --> 510             self._load_lines()
#     511
#
# ~/anaconda3/lib/python3.6/traceback.py in _load_lines(self)
#     521         if self.__context__:
# --> 522             self.__context__._load_lines()
#     523         if self.__cause__:
#
# ~/anaconda3/lib/python3.6/traceback.py in _load_lines(self)
#     521         if self.__context__:
# --> 522             self.__context__._load_lines()
#     523         if self.__cause__:
#
# ~/anaconda3/lib/python3.6/traceback.py in _load_lines(self)
#     519         for frame in self.stack:
# --> 520             frame.line
#     521         if self.__context__:
#
# ~/anaconda3/lib/python3.6/traceback.py in line(self)
#     281         if self._line is None:
# --> 282             self._line = linecache.getline(self.filename, self.lineno).strip()
#     283         return self._line
#
# ~/anaconda3/lib/python3.6/linecache.py in getline(filename, lineno, module_globals)
#      15 def getline(filename, lineno, module_globals=None):
# ---> 16     lines = getlines(filename, module_globals)
#      17     if 1 <= lineno <= len(lines):
#
# ~/anaconda3/lib/python3.6/linecache.py in getlines(filename, module_globals)
#      46     try:
# ---> 47         return updatecache(filename, module_globals)
#      48     except MemoryError:
#
# ~/anaconda3/lib/python3.6/linecache.py in updatecache(filename, module_globals)
#     136         with tokenize.open(fullname) as fp:
# --> 137             lines = fp.readlines()
#     138     except OSError:
#
# ~/anaconda3/lib/python3.6/codecs.py in decode(self, input, final)
#     317
# --> 318     def decode(self, input, final=False):
#     319         # decode input (taking the buffer into account)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_code(self, code_obj, result)
#    2877             if result is not None:
#    2878                 result.error_in_exec = sys.exc_info()[1]
# -> 2879             self.showtraceback(running_compiled_code=True)
#    2880         else:
#    2881             outflag = False
#
# ~/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    1819
#    1820         except KeyboardInterrupt:
# -> 1821             print('\n' + self.get_exception_only(), file=sys.stderr)
#    1822
#    1823     def _showtraceback(self, etype, evalue, stb):
#
# ~/anaconda3/lib/python3.6/site-packages/ipykernel/iostream.py in write(self, string)
#     350             is_child = (not self._is_master_process())
#     351             # only touch the buffer in the IO thread to avoid races
# --> 352             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     353             if is_child:
#     354                 # newlines imply flush in subprocesses
#
# ~/anaconda3/lib/python3.6/site-packages/ipykernel/iostream.py in schedule(self, f)
#     188                 event_id = os.urandom(16)
#     189             self._events[event_id] = f
# --> 190             self._event_pipe.send(event_id)
#     191         else:
#     192             f()
#
# ~/anaconda3/lib/python3.6/site-packages/zmq/backend/cffi/socket.py in send(self, message, flags, copy, track)
#     187         _check_rc(rc)
#     188         C.memcpy(C.zmq_msg_data(zmq_msg), c_message, len(message))
# --> 189         _retry_sys_call(C.zmq_msg_send, zmq_msg, self._zmq_socket, flags)
#     190         rc2 = C.zmq_msg_close(zmq_msg)
#     191         _check_rc(rc2)
#
# ~/anaconda3/lib/python3.6/site-packages/zmq/backend/cffi/utils.py in _retry_sys_call(f, *args, **kwargs)
#      46     """make a call, retrying if interrupted with EINTR"""
#      47     while True:
# ---> 48         rc = f(*args)
#      49         try:
#      50             _check_rc(rc)
#
# KeyboardInterrupt:
# ERROR:tornado.general:Uncaught exception, closing connection.
# Traceback (most recent call last):
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2706, in run_cell
#     self.events.trigger('post_execute')
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/IPython/core/events.py", line 73, in trigger
#     func(*args, **kwargs)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/ipykernel/pylab/backend_inline.py", line 113, in flush_figures
#     return show(True)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/ipykernel/pylab/backend_inline.py", line 36, in show
#     display(figure_manager.canvas.figure)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/IPython/core/display.py", line 302, in display
#     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/IPython/core/formatters.py", line 171, in format
#     data = formatter(obj)
#   File "<decorator-gen-9>", line 2, in __call__
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/IPython/core/formatters.py", line 215, in catch_format_error
#     r = method(self, *args, **kwargs)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/IPython/core/formatters.py", line 332, in __call__
#     return printer(obj)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/IPython/core/pylabtools.py", line 237, in <lambda>
#     png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/IPython/core/pylabtools.py", line 121, in print_figure
#     fig.canvas.print_figure(bytes_io, **kw)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/matplotlib/backend_bases.py", line 2212, in print_figure
#     **kwargs)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py", line 528, in print_png
#     self.figure.dpi, metadata=metadata)
# KeyboardInterrupt
# ERROR:tornado.general:Uncaught exception, closing connection.
# Traceback (most recent call last):
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2706, in run_cell
#     self.events.trigger('post_execute')
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/IPython/core/events.py", line 73, in trigger
#     func(*args, **kwargs)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/ipykernel/pylab/backend_inline.py", line 113, in flush_figures
#     return show(True)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/ipykernel/pylab/backend_inline.py", line 36, in show
#     display(figure_manager.canvas.figure)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/IPython/core/display.py", line 302, in display
#     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/IPython/core/formatters.py", line 171, in format
#     data = formatter(obj)
#   File "<decorator-gen-9>", line 2, in __call__
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/IPython/core/formatters.py", line 215, in catch_format_error
#     r = method(self, *args, **kwargs)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/IPython/core/formatters.py", line 332, in __call__
#     return printer(obj)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/IPython/core/pylabtools.py", line 237, in <lambda>
#     png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/IPython/core/pylabtools.py", line 121, in print_figure
#     fig.canvas.print_figure(bytes_io, **kw)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/matplotlib/backend_bases.py", line 2212, in print_figure
#     **kwargs)
#   File "/Users/gordon.blackadder/anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py", line 528, in print_png
#     self.figure.dpi, metadata=metadata)
# KeyboardInterrupt
